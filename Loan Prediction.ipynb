# %%
#include library

import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read Data
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#Data Description

df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
#Handling missing data >>> using mean value

df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Handling missing catagorical data

df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
# Here mode shows male is more than female. so fill with this data
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df['Married'].mode()
# Out:
# 0    Yes
# Name: Married, dtype: object

# %%
df['Married'].mode()[0]
# Out:
# 'Yes'

# %%
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Dependents'].mode()
# Out:
# 0    0
# Name: Dependents, dtype: object

# %%
df['Dependents'].mode()[0]
# Out:
# '0'

# %%
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Self_Employed'].mode()
# Out:
# 0    No
# Name: Self_Employed, dtype: object

# %%
df['Self_Employed'].mode()[0]
# Out:
# 'No'

# %%
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
#                                                                 Exploratory data analysis
#
#                                                                        1. Count Plot

# %%
sns.countplot(x='Gender', data=df)
plt.title('Count of Gender')
plt.xticks(rotation=45)  # Rotate labels if necessary
plt.show()

# %%
# Assuming 'Gender' is a column in your DataFrame
sns.countplot(x='Gender', data=df)
plt.show()

# same code
#sns.countplot(x='Married', data=df)
#plt.show()

# %% [markdown]
#                                                                         Bar plot

# %%
df.groupby(['Gender', 'Married']).size().unstack().plot(kind='bar', stacked=True)
plt.title('Stacked Bar Plot of Two Categorical Variables')
plt.show()

# %%
df['Married'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Married')
plt.ylabel('')  # Hide y-label for better aesthetics
plt.show()

# %%
sns.countplot(x='Married', data=df)
plt.show()

# %%
sns.distplot(df.CoapplicantIncome)
#plt.show()
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Density'>

# %%
#
#df['CoapplicantIncome_log']= np.log(df['CoapplicantIncome'])
#sns.distplot(df.CoapplicantIncome_log)


#df['CoapplicantIncome_log']= np.log1p(df['CoapplicantIncome'])
#sns.distplot(df.CoapplicantIncome_log)

# %%
# Calculating mean, median, and mode for column 'A'
mean_A = df['CoapplicantIncome'].mean()        # Mean
median_A = df['CoapplicantIncome'].median()     # Median
mode_A = df['CoapplicantIncome'].mode()         # Mode (returns a Series)

print("Mean of column A:", mean_A)
print("Median of column A:", median_A)
print("Mode of column A:", mode_A.values)
# Out:
# Mean of column A: 1621.2457980271008
# Median of column A: 1188.5
# Mode of column A: [0.]

# %%
# upon Shows data is not normally distributed

#import pandas as pd
#import numpy as np
#import matplotlib.pyplot as plt
from sklearn.preprocessing import PowerTransformer

# Sample data: Replace this with your actual DataFrame
# data = pd.read_csv("your_file.csv")
# Assuming your data is in a column named 'CoapplicantIncome'
# For example:
# data = pd.DataFrame({"CoapplicantIncome": [1, 2, 3, ...]})

# Log Transformation
df['log_income'] = np.log1p(df['CoapplicantIncome'])  # np.log1p is log(x + 1) to handle zero values

# Square Root Transformation
df['sqrt_income'] = np.sqrt(df['CoapplicantIncome'])

# Box-Cox Transformation (only works for positive data)
#pt_boxcox = PowerTransformer(method='box-cox')
#df['boxcox_income'] = pt_boxcox.fit_transform(df[['CoapplicantIncome']])

# Plot the results to compare distributions
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Original Data
axes[0].hist(df['CoapplicantIncome'], bins=30, color='skyblue', edgecolor='black', density=True)
axes[0].set_title('Original Data')
axes[0].set_xlabel('CoapplicantIncome')
axes[0].set_ylabel('Density')

# Log Transformation
axes[1].hist(df['log_income'], bins=30, color='lightgreen', edgecolor='black', density=True)
axes[1].set_title('Log Transformation')
axes[1].set_xlabel('log(CoapplicantIncome + 1)')
axes[1].set_ylabel('Density')

# Square Root Transformation
axes[2].hist(df['sqrt_income'], bins=30, color='salmon', edgecolor='black', density=True)
axes[2].set_title('Square Root Transformation')
axes[2].set_xlabel('sqrt(CoapplicantIncome)')
axes[2].set_ylabel('Density')

# Box-Cox Transformation >>> Only for positive data
#axes[3].hist(df['boxcox_income'], bins=30, color='gold', edgecolor='black', density=True)
#axes[3].set_title('Box-Cox Transformation')
#axes[3].set_xlabel('Box-Cox(CoapplicantIncome)')
#axes[3].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
sns.distplot(df.LoanAmount)
#plt.show()
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
# Sample data: Replace this with your actual DataFrame
# data = pd.read_csv("your_file.csv")
# Assuming your data is in a column named 'CoapplicantIncome'
# For example:
# data = pd.DataFrame({"CoapplicantIncome": [1, 2, 3, ...]})

# Log Transformation
df['LoanAmount'] = np.log1p(df['LoanAmount'])  # np.log1p is log(x + 1) to handle zero values

# Square Root Transformation
df['LoanAmount'] = np.sqrt(df['LoanAmount'])

# Box-Cox Transformation (only works for positive data)
#pt_boxcox = PowerTransformer(method='box-cox')
#df['boxcox_income'] = pt_boxcox.fit_transform(df[['CoapplicantIncome']])

# Plot the results to compare distributions
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Original Data
axes[0].hist(df['LoanAmount'], bins=30, color='skyblue', edgecolor='black', density=True)
axes[0].set_title('Original Data')
axes[0].set_xlabel('CoapplicantIncome')
axes[0].set_ylabel('Density')

# Log Transformation
axes[1].hist(df['LoanAmount'], bins=30, color='lightgreen', edgecolor='black', density=True)
axes[1].set_title('Log Transformation')
axes[1].set_xlabel('log(CoapplicantIncome + 1)')
axes[1].set_ylabel('Density')

# Square Root Transformation
axes[2].hist(df['sqrt_income'], bins=30, color='salmon', edgecolor='black', density=True)
axes[2].set_title('Square Root Transformation')
axes[2].set_xlabel('sqrt(CoapplicantIncome)')
axes[2].set_ylabel('Density')

# Box-Cox Transformation >>> Only for positive data
#axes[3].hist(df['boxcox_income'], bins=30, color='gold', edgecolor='black', density=True)
#axes[3].set_title('Box-Cox Transformation')
#axes[3].set_xlabel('Box-Cox(CoapplicantIncome)')
#axes[3].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
# Calculating mean, median, and mode for column 'A'
mean_A = df['LoanAmount'].mean()        # Mean
median_A = df['LoanAmount'].median()     # Median
mode_A = df['LoanAmount'].mode()         # Mode (returns a Series)

print("Mean of column A:", mean_A)
print("Median of column A:", median_A)
print("Mode of column A:", mode_A.values)
# Out:
# Mean of column A: 2.204117989727622
# Median of column A: 2.2062489547772213
# Mode of column A: [2.2345542]

# %%
sns.distplot(df.Loan_Amount_Term)
#plt.show()
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
sns.distplot(df.Credit_History)
#plt.show()
# Out:
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  log_income         614 non-null    float64
#  14  sqrt_income        614 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# log_income           0
# sqrt_income          0
# dtype: int64

# %%
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Categories')
plt.ylabel('')  # Hide y-label for better aesthetics
plt.show()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0    2.234554             360.0
# 1             4583             1508.0    2.204498             360.0
# 2             3000                0.0    2.050535             360.0
# 3             2583             2358.0    2.189929             360.0
# 4             6000                0.0    2.226169             360.0
#
#    Credit_History Property_Area Loan_Status  log_income  sqrt_income
# 0             1.0         Urban           Y    0.000000     0.000000
# ...

# %%
# as here ApplicantIncome and CoapplicantIncome can be combined . because this resembles couples money

df['total_income']= df['ApplicantIncome']+df['CoapplicantIncome']

# %%
#df.head()
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df= df.drop(['ApplicantIncome'], axis=1)
df= df.drop(['CoapplicantIncome'], axis=1)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status  \
# ...

# %%
# Calculating mean, median, and mode for column 'total_income'
mean_total_income = df['total_income'].mean()        # Mean
median_total_income = df['total_income'].median()     # Median
mode_total_income = df['total_income'].mode()         # Mode (returns a Series)

print("Mean of column A:", mean_total_income)
print("Median of column A:", median_total_income)
print("Mode of column A:", mode_total_income.values)
# Out:
# Mean of column A: 7024.705081414722
# Median of column A: 5416.5
# Mode of column A: [6000.]

# %%
# Sample data: Replace this with your actual DataFrame
# data = pd.read_csv("your_file.csv")
# Assuming your data is in a column named 'CoapplicantIncome'
# For example:
# data = pd.DataFrame({"CoapplicantIncome": [1, 2, 3, ...]})

# Log Transformation
df['total_income'] = np.log1p(df['total_income'])  # np.log1p is log(x + 1) to handle zero values

# Square Root Transformation
df['total_income'] = np.sqrt(df['total_income'])

# Box-Cox Transformation (only works for positive data)
#pt_boxcox = PowerTransformer(method='box-cox')
#df['boxcox_income'] = pt_boxcox.fit_transform(df[['CoapplicantIncome']])

# Plot the results to compare distributions
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Original Data
axes[0].hist(df['total_income'], bins=30, color='skyblue', edgecolor='black', density=True)
axes[0].set_title('Original Data')
axes[0].set_xlabel('CoapplicantIncome')
axes[0].set_ylabel('Density')

# Log Transformation
axes[1].hist(df['total_income'], bins=30, color='lightgreen', edgecolor='black', density=True)
axes[1].set_title('Log Transformation')
axes[1].set_xlabel('log(CoapplicantIncome + 1)')
axes[1].set_ylabel('Density')

# Square Root Transformation
axes[2].hist(df['sqrt_income'], bins=30, color='salmon', edgecolor='black', density=True)
axes[2].set_title('Square Root Transformation')
axes[2].set_xlabel('sqrt(CoapplicantIncome)')
axes[2].set_ylabel('Density')

# Box-Cox Transformation >>> Only for positive data
#axes[3].hist(df['boxcox_income'], bins=30, color='gold', edgecolor='black', density=True)
#axes[3].set_title('Box-Cox Transformation')
#axes[3].set_xlabel('Box-Cox(CoapplicantIncome)')
#axes[3].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
sns.distplot(df.total_income)
# Out:
# <Axes: xlabel='total_income', ylabel='Density'>

# %%
#sns.distplot(df.total_income)
df['total_income'] = np.log1p(df['total_income'])
sns.distplot(df.total_income)

#plt.show()
# Out:
# <Axes: xlabel='total_income', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Loan_ID           614 non-null    object
#  1   Gender            614 non-null    object
#  2   Married           614 non-null    object
#  3   Dependents        614 non-null    object
#  4   Education         614 non-null    object
#  5   Self_Employed     614 non-null    object
#  6   LoanAmount        614 non-null    float64
#  7   Loan_Amount_Term  614 non-null    float64
#  8   Credit_History    614 non-null    float64
#  9   Property_Area     614 non-null    object
#  10  Loan_Status       614 non-null    object
#  11  log_income        614 non-null    float64
#  12  sqrt_income       614 non-null    float64
#  13  total_income      614 non-null    float64
# dtypes: float64(6), object(8)
# memory usage: 67.3+ KB

# %%
# Normal Distribution


# Calculating mean, median, and mode for column 'total_income'
mean_LoanAmount = df['LoanAmount'].mean()        # Mean
median_LoanAmount = df['LoanAmount'].median()     # Median
mode_LoanAmount = df['LoanAmount'].mode()         # Mode (returns a Series)

print("Mean of column A:", mean_LoanAmount)
print("Median of column A:", median_LoanAmount)
print("Mode of column A:", mode_LoanAmount.values)
# Out:
# Mean of column A: 2.204117989727622
# Median of column A: 2.2062489547772213
# Mode of column A: [2.2345542]

# %%
#Mean == Median == Mode >>> Normally Distributed
#So there is no need to transform into Normal Distribution

# %%
# Sample data: Replace this with your actual DataFrame
# data = pd.read_csv("your_file.csv")
# Assuming your data is in a column named 'CoapplicantIncome'
# For example:
# data = pd.DataFrame({"CoapplicantIncome": [1, 2, 3, ...]})

# Log Transformation
#df['LoanAmount'] = np.log1p(df['LoanAmount'])  # np.log1p is log(x + 1) to handle zero values

# Square Root Transformation
#df['LoanAmount'] = np.sqrt(df['LoanAmount'])

# Box-Cox Transformation (only works for positive data)
#pt_boxcox = PowerTransformer(method='box-cox')
#df['boxcox_income'] = pt_boxcox.fit_transform(df[['CoapplicantIncome']])

# Plot the results to compare distributions
#fig, axes = plt.subplots(2, 2, figsize=(12, 10))
#axes = axes.flatten()

# Original Data
#axes[0].hist(df['LoanAmount'], bins=30, color='skyblue', edgecolor='black', density=True)
#axes[0].set_title('Original Data')
#axes[0].set_xlabel('CoapplicantIncome')
#axes[0].set_ylabel('Density')

# Log Transformation
#axes[1].hist(df['LoanAmount'], bins=30, color='lightgreen', edgecolor='black', density=True)
#axes[1].set_title('Log Transformation')
#axes[1].set_xlabel('log(CoapplicantIncome + 1)')
#axes[1].set_ylabel('Density')

# Square Root Transformation
#axes[2].hist(df['sqrt_income'], bins=30, color='salmon', edgecolor='black', density=True)
#axes[2].set_title('Square Root Transformation')
#axes[2].set_xlabel('sqrt(CoapplicantIncome)')
#axes[2].set_ylabel('Density')

# Box-Cox Transformation >>> Only for positive data
#axes[3].hist(df['boxcox_income'], bins=30, color='gold', edgecolor='black', density=True)
#axes[3].set_title('Box-Cox Transformation')
#axes[3].set_xlabel('Box-Cox(CoapplicantIncome)')
#axes[3].set_ylabel('Density')

#plt.tight_layout()
#plt.show()

# %%
# Normal Distribution


# Calculating mean, median, and mode for column 'total_income'
mean_Loan_Amount_Term = df['Loan_Amount_Term'].mean()        # Mean
median_Loan_Amount_Term = df['Loan_Amount_Term'].median()     # Median
mode_Loan_Amount_Term = df['Loan_Amount_Term'].mode()         # Mode (returns a Series)

print("Mean of column A:", mean_Loan_Amount_Term)
print("Median of column A:", median_Loan_Amount_Term)
print("Mode of column A:", mode_Loan_Amount_Term.values)
# Out:
# Mean of column A: 342.0
# Median of column A: 360.0
# Mode of column A: [360.]

# %%
# positive Skewed

# %%
# Sample data: Replace this with your actual DataFrame
# data = pd.read_csv("your_file.csv")
# Assuming your data is in a column named 'CoapplicantIncome'
# For example:
# data = pd.DataFrame({"CoapplicantIncome": [1, 2, 3, ...]})

# Log Transformation
df['Loan_Amount_Term'] = np.log1p(df['Loan_Amount_Term'])  # np.log1p is log(x + 1) to handle zero values

# Square Root Transformation
df['Loan_Amount_Term'] = np.sqrt(df['Loan_Amount_Term'])

# Box-Cox Transformation (only works for positive data)
pt_boxcox = PowerTransformer(method='box-cox')
df['boxcox_income'] = pt_boxcox.fit_transform(df[['Loan_Amount_Term']])

# Plot the results to compare distributions
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Original Data
axes[0].hist(df['Loan_Amount_Term'], bins=30, color='skyblue', edgecolor='black', density=True)
axes[0].set_title('Original Data')
axes[0].set_xlabel('CoapplicantIncome')
axes[0].set_ylabel('Density')

# Log Transformation
axes[1].hist(df['Loan_Amount_Term'], bins=30, color='lightgreen', edgecolor='black', density=True)
axes[1].set_title('Log Transformation')
axes[1].set_xlabel('log(CoapplicantIncome + 1)')
axes[1].set_ylabel('Density')

# Square Root Transformation
axes[2].hist(df['sqrt_income'], bins=30, color='salmon', edgecolor='black', density=True)
axes[2].set_title('Square Root Transformation')
axes[2].set_xlabel('sqrt(CoapplicantIncome)')
axes[2].set_ylabel('Density')

# Box-Cox Transformation >>> Only for positive data
axes[3].hist(df['boxcox_income'], bins=30, color='gold', edgecolor='black', density=True)
axes[3].set_title('Box-Cox Transformation')
axes[3].set_xlabel('Box-Cox(CoapplicantIncome)')
axes[3].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status  \
# ...
